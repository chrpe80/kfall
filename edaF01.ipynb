# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from prepare_df_F01 import data

# %%
data.head(5)
# Out:
#     AccX   AccY   AccZ      GyrX      GyrY      GyrZ     EulerX    EulerY  \
# 0 -0.058 -1.007  0.027 -1.776170 -0.802141 -0.057296  91.879545 -1.758981
# 1 -0.055 -1.003  0.021 -2.177240  0.515662 -0.171887  91.856627 -1.758981
# 2 -0.054 -1.004  0.018 -2.119945  0.630254 -0.114592  91.833708 -1.753251
# 3 -0.055 -1.006  0.017 -2.005353  0.515662 -0.114592  91.810790 -1.753251
# 4 -0.059 -1.006  0.020 -1.890761  0.630254 -0.171887  91.742035 -1.822006
#
#       EulerZ  Class
# 0 -25.880513      0
# 1 -25.874783      0
# 2 -25.869054      0
# 3 -25.863324      0
# 4 -25.828947      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22355 entries, 0 to 736
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AccX    22355 non-null  float64
#  1   AccY    22355 non-null  float64
#  2   AccZ    22355 non-null  float64
#  3   GyrX    22355 non-null  float64
#  4   GyrY    22355 non-null  float64
#  5   GyrZ    22355 non-null  float64
#  6   EulerX  22355 non-null  float64
#  7   EulerY  22355 non-null  float64
#  8   EulerZ  22355 non-null  float64
#  9   Class   22355 non-null  int64
# dtypes: float64(9), int64(1)
# memory usage: 1.9 MB

# %%
data.isnull().sum()
# Out:
# AccX      0
# AccY      0
# AccZ      0
# GyrX      0
# GyrY      0
# GyrZ      0
# EulerX    0
# EulerY    0
# EulerZ    0
# Class     0
# dtype: int64

# %%
data.corr()
# Out:
#             AccX      AccY      AccZ      GyrX      GyrY      GyrZ    EulerX  \
# AccX    1.000000  0.293397 -0.296731 -0.011424 -0.186215 -0.170923 -0.253634
# AccY    0.293397  1.000000 -0.738018  0.146976 -0.049607 -0.030811 -0.861210
# AccZ   -0.296731 -0.738018  1.000000 -0.009505  0.013275  0.063965  0.802161
# GyrX   -0.011424  0.146976 -0.009505  1.000000 -0.055598  0.375372 -0.063308
# GyrY   -0.186215 -0.049607  0.013275 -0.055598  1.000000  0.030073  0.019670
# GyrZ   -0.170923 -0.030811  0.063965  0.375372  0.030073  1.000000 -0.010318
# EulerX -0.253634 -0.861210  0.802161 -0.063308  0.019670 -0.010318  1.000000
# EulerY  0.592361  0.380796 -0.330687  0.002120  0.015647 -0.119355 -0.394190
# EulerZ  0.147721  0.022966 -0.036117 -0.027965  0.059252 -0.026196 -0.016064
# Class   0.245792  0.835181 -0.739159  0.184779 -0.024249  0.036692 -0.902757
#
#           EulerY    EulerZ     Class
# AccX    0.592361  0.147721  0.245792
# AccY    0.380796  0.022966  0.835181
# AccZ   -0.330687 -0.036117 -0.739159
# GyrX    0.002120 -0.027965  0.184779
# GyrY    0.015647  0.059252 -0.024249
# GyrZ   -0.119355 -0.026196  0.036692
# EulerX -0.394190 -0.016064 -0.902757
# EulerY  1.000000  0.248262  0.387240
# EulerZ  0.248262  1.000000  0.019677
# Class   0.387240  0.019677  1.000000

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=data, x="AccY", y="AccZ", hue="Class");

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True);

# %%
sns.countplot(x="Class", data=data);
